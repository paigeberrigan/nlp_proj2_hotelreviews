# %%
# imports and helper functions 
import os
import sys

# set project root 
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
    
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from prettytable import PrettyTable
import joblib
from sklearn.metrics import classification_report

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Activation, Input
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback, EarlyStopping
from tensorflow.keras.regularizers import l2

#  helper Functions
from helpers.visualization_helpers import plot_confusion_matrix, print_classification_report

# %%
# load all preprocessed data

# 3 vectorizers
bow_vectorizer = joblib.load('../outputs/models/bow_vectorizer.joblib')
tfidf_vectorizer = joblib.load('../outputs/models/tfidf_vectorizer.joblib')
spacy_model = joblib.load('../outputs/models/spacy_model.joblib')

# Load in training data
X_train_tfidf = joblib.load('../outputs/models/X_train_tfidf_balanced.joblib')
X_train_bow = joblib.load('../outputs/models/X_train_bow_balanced.joblib')
X_train_spacy = joblib.load('../outputs/models/X_train_spacy_balanced.joblib')

y_train_tfidf = joblib.load('../outputs/models/y_train_tfidf_balanced.joblib')
y_train_bow = joblib.load('../outputs/models/y_train_bow_balanced.joblib')
y_train_spacy = joblib.load('../outputs/models/y_train_spacy_balanced.joblib')

print("Preprocessed data loaded successfully.")
# Out:
# Preprocessed data loaded successfully.

# %%
# Number of classes for 5 ratings
num_classes = 5

# Function to prepare data for NN
def prepare_nn_data(X, y):
    y_cat = to_categorical(y - 1, num_classes)  # move labels to start from 0
    if hasattr(X, 'toarray'):
        X = X.toarray()  # make into dense
    return X, y_cat

# %%
# use a pretty table to log everything and make clear 
class TrainingLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        table = PrettyTable()
        table.field_names = ["Epoch", "Training Loss", "Training Accuracy", "Validation Loss", "Validation Accuracy"]
        table.add_row([
            epoch + 1,
            logs.get("loss"),
            logs.get("accuracy"),
            logs.get("val_loss"),
            logs.get("val_accuracy")
        ])
        print(table)

# %%
# Neural Network with TFIDF
X_nn_tfidf, y_nn_tfidf = prepare_nn_data(X_train_tfidf, y_train_tfidf)

nn_tfidf = Sequential([
    Input(shape=(X_nn_tfidf.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

nn_tfidf.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_tfidf = nn_tfidf.fit(
    X_nn_tfidf, y_nn_tfidf, 
    validation_split=0.2,  # Using validation split for validation metrics
    epochs=5, 
    batch_size=32, 
    callbacks=[TrainingLogger()]
)
nn_tfidf.save('../outputs/models/Neural_Network_TFIDF.keras')
# Out:
# Epoch 1/5
# 903/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6229 - loss: 0.9123+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   1   | 0.6570318937301636 | 0.7273919582366943 | 0.8138411641120911 |  0.6718210577964783 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.6233 - loss: 0.9112 - val_accuracy: 0.6718 - val_loss: 0.8138
# Epoch 2/5
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8630 - loss: 0.3420+-------+---------------------+-------------------+--------------------+---------------------+
# | Epoch |    Training Loss    | Training Accuracy |  Validation Loss   | Validation Accuracy |
# +-------+---------------------+-------------------+--------------------+---------------------+
# |   2   | 0.34607067704200745 | 0.857172429561615 | 0.5189093947410583 |  0.8217589259147644 |
# +-------+---------------------+-------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8630 - loss: 0.3420 - val_accuracy: 0.8218 - val_loss: 0.5189
# Epoch 3/5
# 893/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9059 - loss: 0.2340+-------+---------------------+--------------------+---------------------+---------------------+
# | Epoch |    Training Loss    | Training Accuracy  |   Validation Loss   | Validation Accuracy |
# +-------+---------------------+--------------------+---------------------+---------------------+
# |   3   | 0.24717827141284943 | 0.8966243267059326 | 0.30761709809303284 |  0.8866491913795471 |
# +-------+---------------------+--------------------+---------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9057 - loss: 0.2342 - val_accuracy: 0.8866 - val_loss: 0.3076
# Epoch 4/5
# 897/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9418 - loss: 0.1588+-------+---------------------+--------------------+---------------------+---------------------+
# | Epoch |    Training Loss    | Training Accuracy  |   Validation Loss   | Validation Accuracy |
# +-------+---------------------+--------------------+---------------------+---------------------+
# |   4   | 0.16986121237277985 | 0.9333494305610657 | 0.19727708399295807 |  0.9276542663574219 |
# +-------+---------------------+--------------------+---------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9417 - loss: 0.1589 - val_accuracy: 0.9277 - val_loss: 0.1973
# Epoch 5/5
# 895/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9728 - loss: 0.0879+-------+---------------------+--------------------+---------------------+---------------------+
# | Epoch |    Training Loss    | Training Accuracy  |   Validation Loss   | Validation Accuracy |
# +-------+---------------------+--------------------+---------------------+---------------------+
# |   5   | 0.09231510758399963 | 0.9681761860847473 | 0.08592686802148819 |  0.9787380695343018 |
# +-------+---------------------+--------------------+---------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9727 - loss: 0.0879 - val_accuracy: 0.9787 - val_loss: 0.0859

# %%
# define the bow model
X_nn_bow, y_nn_bow = prepare_nn_data(X_train_bow, y_train_bow)

# added for BOW l2 regularization and a small dropout. Still severe overfitting
nn_bow = Sequential([
    Input(shape=(X_nn_bow.shape[1],)),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.1),
    Dense(64,activation='relu'),
    Dense(num_classes, activation='softmax')
])


# compile
nn_bow.compile(optimizer=Adam(learning_rate=0.001), 
               loss='categorical_crossentropy', 
               metrics=['accuracy'])

# callback for early stopping pending validation loss
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# train BOW + NN
history_bow = nn_bow.fit(
    X_nn_bow, y_nn_bow, 
    validation_split=0.2,  
    epochs=50,           
    batch_size=32,        
    callbacks=[TrainingLogger(), early_stopping]
)

# save to job lib files
nn_bow.save('../outputs/models/Neural_Network_BOW.keras')
# Out:
# Epoch 1/50
# 894/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5846 - loss: 1.0964+-------+-------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+-------------------+--------------------+-------------------+---------------------+
# |   1   | 0.949047327041626 | 0.6512494683265686 | 1.925663948059082 |  0.2398177534341812 |
# +-------+-------------------+--------------------+-------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5855 - loss: 1.0943 - val_accuracy: 0.2398 - val_loss: 1.9257
# Epoch 2/50
# 900/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7450 - loss: 0.7759+-------+--------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+-------------------+---------------------+
# |   2   | 0.7971948981285095 | 0.7396106719970703 | 2.200166702270508 | 0.17230428755283356 |
# +-------+--------------------+--------------------+-------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.7450 - loss: 0.7761 - val_accuracy: 0.1723 - val_loss: 2.2002
# Epoch 3/50
# 897/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7938 - loss: 0.7028+-------+-------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+-------------------+--------------------+-------------------+---------------------+
# |   3   | 0.741895318031311 | 0.7799599766731262 | 2.149656057357788 |  0.2867596447467804 |
# +-------+-------------------+--------------------+-------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7937 - loss: 0.7032 - val_accuracy: 0.2868 - val_loss: 2.1497
# Epoch 4/50
# 901/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8287 - loss: 0.6718+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   4   | 0.7120471596717834 | 0.8130953907966614 | 2.2214365005493164 | 0.30898797512054443 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8286 - loss: 0.6721 - val_accuracy: 0.3090 - val_loss: 2.2214
# Epoch 5/50
# 898/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8545 - loss: 0.6395+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   5   | 0.6757441759109497 | 0.8384302258491516 | 1.9682639837265015 | 0.42799943685531616 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8544 - loss: 0.6398 - val_accuracy: 0.4280 - val_loss: 1.9683
# Epoch 6/50
# 904/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8712 - loss: 0.6116+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   6   | 0.6532378196716309 | 0.8552395701408386 | 2.0881452560424805 |  0.3842330574989319 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8711 - loss: 0.6118 - val_accuracy: 0.3842 - val_loss: 2.0881
# Epoch 7/50
# 890/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8957 - loss: 0.5847+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   7   | 0.6297931671142578 | 0.8756730556488037 | 2.1170132160186768 | 0.41681623458862305 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8954 - loss: 0.5855 - val_accuracy: 0.4168 - val_loss: 2.1170
# Epoch 8/50
# 894/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9082 - loss: 0.5741+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   8   | 0.6127579212188721 | 0.8929311037063599 | 2.1883997917175293 | 0.42841362953186035 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9080 - loss: 0.5746 - val_accuracy: 0.4284 - val_loss: 2.1884
# Epoch 9/50
# 894/906 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9154 - loss: 0.5679+-------+--------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+-------------------+---------------------+
# |   9   | 0.6052846908569336 | 0.9004901051521301 | 2.032827615737915 | 0.49068066477775574 |
# +-------+--------------------+--------------------+-------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9152 - loss: 0.5684 - val_accuracy: 0.4907 - val_loss: 2.0328
# Epoch 10/50
# 889/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9235 - loss: 0.5549+-------+--------------------+--------------------+------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  | Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+------------------+---------------------+
# |   10  | 0.5860173106193542 | 0.9091882109642029 | 2.23923397064209 |  0.450503945350647  |
# +-------+--------------------+--------------------+------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9232 - loss: 0.5555 - val_accuracy: 0.4505 - val_loss: 2.2392
# Epoch 11/50
# 894/906 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9261 - loss: 0.5560+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   11  | 0.5868812203407288 | 0.9113627076148987 | 2.2770578861236572 |  0.4297942817211151 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 906/906 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9259 - loss: 0.5564 - val_accuracy: 0.4298 - val_loss: 2.2771

# %%
# Neural Network with spaCy
X_nn_spacy, y_nn_spacy = prepare_nn_data(X_train_spacy, y_train_spacy)

nn_spacy = Sequential([
    Input(shape=(X_nn_spacy.shape[1],)),
    Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(64,activation='relu'),
    Dense(num_classes, activation='softmax')
])


early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

nn_spacy.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
history_spacy = nn_spacy.fit(
    X_nn_spacy, y_nn_spacy,
    validation_split=0.1, # made small
    epochs=200,  # Increased epochs 50-> 200
    batch_size=16,# 32 -> 64
    callbacks=[TrainingLogger(), early_stopping]
)

nn_spacy.save('../outputs/models/Neural_Network_SPACY.keras')
# Out:
# Epoch 1/200
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4604 - loss: 1.4287+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   1   | 1.2885297536849976 | 0.5139753818511963 | 1.3173000812530518 | 0.44119271636009216 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.4604 - loss: 1.4286 - val_accuracy: 0.4412 - val_loss: 1.3173
# Epoch 2/200
# 2037/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5785 - loss: 1.1281+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   2   | 1.1161863803863525 | 0.5809529423713684 | 1.5977320671081543 | 0.22032026946544647 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5785 - loss: 1.1281 - val_accuracy: 0.2203 - val_loss: 1.5977
# Epoch 3/200
# 2001/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5952 - loss: 1.0725+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   3   | 1.0636776685714722 | 0.6020004153251648 | 1.3279372453689575 |  0.3724461495876312 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5953 - loss: 1.0723 - val_accuracy: 0.3724 - val_loss: 1.3279
# Epoch 4/200
# 2027/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6134 - loss: 1.0347+-------+-------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+-------------------+--------------------+--------------------+---------------------+
# |   4   | 1.028952717781067 | 0.6149479746818542 | 1.3687688112258911 | 0.33821094036102295 |
# +-------+-------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6135 - loss: 1.0347 - val_accuracy: 0.3382 - val_loss: 1.3688
# Epoch 5/200
# 2025/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6259 - loss: 1.0087+-------+--------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+-------------------+---------------------+
# |   5   | 1.0023717880249023 | 0.6267296671867371 | 1.465364694595337 | 0.32523468136787415 |
# +-------+--------------------+--------------------+-------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6259 - loss: 1.0087 - val_accuracy: 0.3252 - val_loss: 1.4654
# Epoch 6/200
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6377 - loss: 0.9817+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   6   | 0.9779670834541321 | 0.6382965445518494 | 1.3048135042190552 |  0.3948094844818115 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6377 - loss: 0.9817 - val_accuracy: 0.3948 - val_loss: 1.3048
# Epoch 7/200
# 2014/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6506 - loss: 0.9576+-------+--------------------+-------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+-------------------+--------------------+---------------------+
# |   7   | 0.9565295577049255 | 0.647010087966919 | 1.3014013767242432 |  0.377139687538147  |
# +-------+--------------------+-------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6505 - loss: 0.9576 - val_accuracy: 0.3771 - val_loss: 1.3014
# Epoch 8/200
# 1995/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6575 - loss: 0.9376+-------+--------------------+--------------------+------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  | Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+------------------+---------------------+
# |   8   | 0.9352999329566956 | 0.6573190689086914 | 1.24435293674469 |  0.4257316291332245 |
# +-------+--------------------+--------------------+------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6575 - loss: 0.9376 - val_accuracy: 0.4257 - val_loss: 1.2444
# Epoch 9/200
# 2021/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6645 - loss: 0.9201+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   9   | 0.9146982431411743 | 0.6664928197860718 | 1.2478528022766113 |  0.4323578178882599 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6646 - loss: 0.9201 - val_accuracy: 0.4324 - val_loss: 1.2479
# Epoch 10/200
# 2028/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6656 - loss: 0.9079+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   10  | 0.8974862694740295 | 0.6716779470443726 | 1.3639310598373413 |  0.3459414541721344 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6656 - loss: 0.9079 - val_accuracy: 0.3459 - val_loss: 1.3639
# Epoch 11/200
# 2035/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6856 - loss: 0.8789+-------+------------------+--------------------+--------------------+---------------------+
# | Epoch |  Training Loss   | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+------------------+--------------------+--------------------+---------------------+
# |   11  | 0.87896728515625 | 0.6842573285102844 | 1.1922303438186646 |  0.4514080584049225 |
# +-------+------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6856 - loss: 0.8789 - val_accuracy: 0.4514 - val_loss: 1.1922
# Epoch 12/200
# 2004/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6907 - loss: 0.8616+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   12  | 0.8618357181549072 | 0.6892890930175781 | 1.3681529760360718 |  0.2973495423793793 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6907 - loss: 0.8616 - val_accuracy: 0.2973 - val_loss: 1.3682
# Epoch 13/200
# 2016/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6951 - loss: 0.8485+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   13  | 0.8449371457099915 | 0.6955788135528564 | 1.3775815963745117 | 0.34400883316993713 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6951 - loss: 0.8484 - val_accuracy: 0.3440 - val_loss: 1.3776
# Epoch 14/200
# 1999/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7080 - loss: 0.8311+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   14  | 0.8291308879852295 | 0.7086797952651978 | 1.2265090942382812 |  0.4160684645175934 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7081 - loss: 0.8311 - val_accuracy: 0.4161 - val_loss: 1.2265
# Epoch 15/200
# 2011/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - accuracy: 0.7200 - loss: 0.8075+-------+-------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+-------------------+--------------------+-------------------+---------------------+
# |   15  | 0.810003936290741 | 0.7147853970527649 | 1.126206874847412 |  0.4552733302116394 |
# +-------+-------------------+--------------------+-------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7200 - loss: 0.8075 - val_accuracy: 0.4553 - val_loss: 1.1262
# Epoch 16/200
# 1997/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7230 - loss: 0.7935+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   16  | 0.7957807779312134 | 0.7205535173416138 | 1.0756723880767822 |  0.5245720744132996 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7229 - loss: 0.7936 - val_accuracy: 0.5246 - val_loss: 1.0757
# Epoch 17/200
# 2030/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7273 - loss: 0.7758+-------+--------------------+-------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+-------------------+--------------------+---------------------+
# |   17  | 0.7825235724449158 | 0.726260244846344 | 1.1352776288986206 |  0.462451696395874  |
# +-------+--------------------+-------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7273 - loss: 0.7758 - val_accuracy: 0.4625 - val_loss: 1.1353
# Epoch 18/200
# 2004/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7303 - loss: 0.7729+-------+--------------------+-------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+-------------------+--------------------+---------------------+
# |   18  | 0.7655848860740662 | 0.734268069267273 | 1.1534281969070435 | 0.45085588097572327 |
# +-------+--------------------+-------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7304 - loss: 0.7728 - val_accuracy: 0.4509 - val_loss: 1.1534
# Epoch 19/200
# 2029/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7400 - loss: 0.7528+-------+-------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+-------------------+--------------------+--------------------+---------------------+
# |   19  | 0.751683235168457 | 0.7400054931640625 | 1.4742923974990845 | 0.30011042952537537 |
# +-------+-------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7400 - loss: 0.7528 - val_accuracy: 0.3001 - val_loss: 1.4743
# Epoch 20/200
# 2023/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7459 - loss: 0.7345+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   20  | 0.7372341752052307 | 0.7455281615257263 | 1.1568247079849243 |  0.4721148610115051 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7459 - loss: 0.7346 - val_accuracy: 0.4721 - val_loss: 1.1568
# Epoch 21/200
# 2004/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7561 - loss: 0.7213+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   21  | 0.7216290235519409 | 0.7540269494056702 | 1.2797913551330566 |  0.3810049593448639 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7561 - loss: 0.7213 - val_accuracy: 0.3810 - val_loss: 1.2798
# Epoch 22/200
# 2028/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7541 - loss: 0.7141+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   22  | 0.7150402665138245 | 0.7537201046943665 | 1.2729376554489136 | 0.40198785066604614 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7541 - loss: 0.7141 - val_accuracy: 0.4020 - val_loss: 1.2729
# Epoch 23/200
# 2021/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7630 - loss: 0.6968+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   23  | 0.7006746530532837 | 0.7616972923278809 | 1.0344305038452148 |  0.5488680005073547 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7629 - loss: 0.6968 - val_accuracy: 0.5489 - val_loss: 1.0344
# Epoch 24/200
# 2015/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7687 - loss: 0.6907+-------+--------------------+-------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+-------------------+--------------------+---------------------+
# |   24  | 0.6870540976524353 | 0.769336998462677 | 1.2078722715377808 |  0.4525124132633209 |
# +-------+--------------------+-------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7687 - loss: 0.6907 - val_accuracy: 0.4525 - val_loss: 1.2079
# Epoch 25/200
# 1995/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7718 - loss: 0.6757+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   25  | 0.6746411919593811 | 0.7719448804855347 | 1.2129063606262207 |  0.4224185645580292 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7718 - loss: 0.6756 - val_accuracy: 0.4224 - val_loss: 1.2129
# Epoch 26/200
# 1996/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7744 - loss: 0.6685+-------+--------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+-------------------+---------------------+
# |   26  | 0.6641765832901001 | 0.7782652974128723 | 1.207112431526184 |  0.3967421352863312 |
# +-------+--------------------+--------------------+-------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7745 - loss: 0.6684 - val_accuracy: 0.3967 - val_loss: 1.2071
# Epoch 27/200
# 2014/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7805 - loss: 0.6612+-------+--------------------+--------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+--------------------+-------------------+---------------------+
# |   27  | 0.6552090644836426 | 0.7843708992004395 | 0.995151698589325 |  0.5654334425926208 |
# +-------+--------------------+--------------------+-------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7805 - loss: 0.6612 - val_accuracy: 0.5654 - val_loss: 0.9952
# Epoch 28/200
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7839 - loss: 0.6491+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   28  | 0.6443539261817932 | 0.7867640256881714 | 1.0842370986938477 |  0.493097722530365  |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7839 - loss: 0.6491 - val_accuracy: 0.4931 - val_loss: 1.0842
# Epoch 29/200
# 2016/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.6320+-------+-------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+-------------------+--------------------+--------------------+---------------------+
# |   29  | 0.632415771484375 | 0.7904765009880066 | 1.1938668489456177 |  0.4334621727466583 |
# +-------+-------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7934 - loss: 0.6320 - val_accuracy: 0.4335 - val_loss: 1.1939
# Epoch 30/200
# 2035/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.6282+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   30  | 0.6269655227661133 | 0.7917957901954651 | 1.3521497249603271 |  0.332965224981308  |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7905 - loss: 0.6282 - val_accuracy: 0.3330 - val_loss: 1.3521
# Epoch 31/200
# 2031/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7933 - loss: 0.6203+-------+--------------------+-------------------+-------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy |  Validation Loss  | Validation Accuracy |
# +-------+--------------------+-------------------+-------------------+---------------------+
# |   31  | 0.6171350479125977 | 0.797165036201477 | 1.153895378112793 |  0.4177250266075134 |
# +-------+--------------------+-------------------+-------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7933 - loss: 0.6203 - val_accuracy: 0.4177 - val_loss: 1.1539
# Epoch 32/200
# 2019/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8040 - loss: 0.6005+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   32  | 0.6079813838005066 | 0.8004786372184753 | 1.0528374910354614 |  0.4977912902832031 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8040 - loss: 0.6006 - val_accuracy: 0.4978 - val_loss: 1.0528
# Epoch 33/200
# 1999/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8026 - loss: 0.5975+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   33  | 0.5994281768798828 | 0.8038535714149475 | 1.0828969478607178 | 0.47625622153282166 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8026 - loss: 0.5975 - val_accuracy: 0.4763 - val_loss: 1.0829
# Epoch 34/200
# 2017/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8055 - loss: 0.5937+-------+-------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss   | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+-------------------+--------------------+--------------------+---------------------+
# |   34  | 0.589402973651886 | 0.8080262541770935 | 1.2046308517456055 | 0.41165101528167725 |
# +-------+-------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8055 - loss: 0.5937 - val_accuracy: 0.4117 - val_loss: 1.2046
# Epoch 35/200
# 2015/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8074 - loss: 0.5865+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   35  | 0.5856220722198486 | 0.8078114986419678 | 1.2082911729812622 | 0.41468802094459534 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8074 - loss: 0.5865 - val_accuracy: 0.4147 - val_loss: 1.2083
# Epoch 36/200
# 2002/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8118 - loss: 0.5737+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   36  | 0.5747709274291992 | 0.8125978112220764 | 1.2632207870483398 |  0.4133075773715973 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8118 - loss: 0.5737 - val_accuracy: 0.4133 - val_loss: 1.2632
# Epoch 37/200
# 2004/2038 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8153 - loss: 0.5688+-------+--------------------+--------------------+--------------------+---------------------+
# | Epoch |   Training Loss    | Training Accuracy  |  Validation Loss   | Validation Accuracy |
# +-------+--------------------+--------------------+--------------------+---------------------+
# |   37  | 0.5664985775947571 | 0.8159420490264893 | 1.0473109483718872 |  0.5309221148490906 |
# +-------+--------------------+--------------------+--------------------+---------------------+
# 2038/2038 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8153 - loss: 0.5688 - val_accuracy: 0.5309 - val_loss: 1.0473

# %%
fig, axes = plt.subplots(2, 3, figsize=(16, 8))

# have all lims start at 0 so its clear to compare across the (2x3)
loss_ylim = (0, max(
    max(history_tfidf.history['loss'] + history_tfidf.history['val_loss']),
    max(history_bow.history['loss'] + history_bow.history['val_loss']),
    max(history_spacy.history['loss'] + history_spacy.history['val_loss'])
) * 1.1)  # add padding 

accuracy_ylim = (0, 1)  # (range is between 0-1)

# TFIDF model loss plot
axes[0, 0].plot(history_tfidf.history['loss'], label='Training Loss')
axes[0, 0].plot(history_tfidf.history['val_loss'], label='Validation Loss')
axes[0, 0].set_title('TFIDF Model Loss')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_ylim(loss_ylim)  
axes[0, 0].legend()

# BOW model loss plot
axes[0, 1].plot(history_bow.history['loss'], label='Training Loss')
axes[0, 1].plot(history_bow.history['val_loss'], label='Validation Loss')
axes[0, 1].set_title('BOW Model Loss')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Loss')
axes[0, 1].set_ylim(loss_ylim) 
axes[0, 1].legend()

# spaCy model loss plot
axes[0, 2].plot(history_spacy.history['loss'], label='Training Loss')
axes[0, 2].plot(history_spacy.history['val_loss'], label='Validation Loss')
axes[0, 2].set_title('spaCy Model Loss')
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Loss')
axes[0, 2].set_ylim(loss_ylim)  
axes[0, 2].legend()

# TFIDF model accuracy plot
axes[1, 0].plot(history_tfidf.history['accuracy'], label='Training Accuracy')
axes[1, 0].plot(history_tfidf.history['val_accuracy'], label='Validation Accuracy')
axes[1, 0].set_title('TFIDF Model Accuracy')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].set_ylim(accuracy_ylim)  
axes[1, 0].legend()

# BOW model accuracy plot
axes[1, 1].plot(history_bow.history['accuracy'], label='Training Accuracy')
axes[1, 1].plot(history_bow.history['val_accuracy'], label='Validation Accuracy')
axes[1, 1].set_title('BOW Model Accuracy')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].set_ylim(accuracy_ylim)  
axes[1, 1].legend()

# spaCy model accuracy plot
axes[1, 2].plot(history_spacy.history['accuracy'], label='Training Accuracy')
axes[1, 2].plot(history_spacy.history['val_accuracy'], label='Validation Accuracy')
axes[1, 2].set_title('spaCy Model Accuracy')
axes[1, 2].set_xlabel('Epochs')
axes[1, 2].set_ylabel('Accuracy')
axes[1, 2].set_ylim(accuracy_ylim)  
axes[1, 2].legend()

plt.tight_layout()
plt.show()
